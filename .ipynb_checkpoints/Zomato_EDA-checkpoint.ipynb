# %% [markdown]
# # Zomato Dataset Exploratory Data Analysis
# - The aim of the experiment is to analyze the Zomato dataset and extract insights to better understand the data.

# %% [markdown]
# #### Import the necessary libraries for Data Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("zomato.csv",encoding="latin")  #read the zomato dataset

# %%
df.head()  # display the sample datapoints in the dataset.
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City
# 0        6317637        Le Petit Souffle           162       Makati City  \
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address
# 0  Third Floor, Century City Mall, Kalayaan Avenu...  \
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality
# 0   Century City Mall, Poblacion, Makati City  \
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.columns  # what are the features in the dataset.
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df.info()  #describe the each feature / columns.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df.describe()  #show the statistics of numerical features in the data.
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude
# count   9.551000e+03   9551.000000  9551.000000  9551.000000  \
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %% [markdown]
# ## Data Analysis
# - 1.Missing value
# - 2.Explore Numerical values
# - 3.Explore Categorical Values
# - 4.Relation between variables

# %%
#finding missing values in the whole dataset
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %% [markdown]
# ## Observation on Missing Values
# - Only the "Cuisines" column has null values in the dataset.

# %%
#finding which columns have missing values
[features for features in df.columns if(df[features].isnull().sum()>0)]
# Out:
# ['Cuisines']

# %%
df.shape  # no.of datapoints and no.of features
# Out:
# (9551, 21)

# %%
df.duplicated().sum()  # no dupliacte data
# Out:
# 0

# %% [markdown]
# - Total 9,551 rows and 21 features/ attributes

# %% [markdown]
# ### Replace the Country Code with Country Name
# - In the dataset, the country code column contains country codes corresponding to their respective countries. Replace the country codes with country names for better understanding.

# %%
df['Country Code'].values  #values in the country code feature
# Out:
# array([162, 162, 162, ..., 208, 208, 208])

# %%
# import the excel which having the country name and correspoding country code
df_country=pd.read_excel("Country-Code.xlsx")

# %%
df_country
# Out:
#     Country Code         Country
# 0              1           India
# 1             14       Australia
# 2             30          Brazil
# 3             37          Canada
# 4             94       Indonesia
# 5            148     New Zealand
# 6            162     Phillipines
# 7            166           Qatar
# 8            184       Singapore
# 9            189    South Africa
# 10           191       Sri Lanka
# 11           208          Turkey
# 12           214             UAE
# 13           215  United Kingdom
# 14           216   United States

# %%
df_country.shape
# Out:
# (15, 2)

# %%
#merge zomato dataset and country dataset based on countrycode
final_data=pd.merge(df,df_country,on="Country Code",how="left")

# %%
final_data.shape
# Out:
# (9551, 22)

# %%
final_data.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
final_data.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City
# 0        6317637        Le Petit Souffle           162       Makati City  \
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address
# 0  Third Floor, Century City Mall, Kalayaan Avenu...  \
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality
# 0   Century City Mall, Poblacion, Makati City  \
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
final_data.dtypes
# Out:
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# Country                  object
# dtype: object

# %%
#How many values are there for each country
final_data.Country.value_counts()
# Out:
# Country
# India             8652
# United States      434
# United Kingdom      80
# Brazil              60
# UAE                 60
# South Africa        60
# New Zealand         40
# Turkey              34
# Australia           24
# Phillipines         22
# Indonesia           21
# Singapore           20
# Qatar               20
# Sri Lanka           20
# Canada               4
# Name: count, dtype: int64

# %% [markdown]
# - Observation: India has the highest number of Zomato orders in the given dataset, followed by the United States

# %%
country_names=final_data.Country.value_counts().index  #store the country names in the variable

# %%
country_names
# Out:
# Index(['India', 'United States', 'United Kingdom', 'Brazil', 'UAE',
#        'South Africa', 'New Zealand', 'Turkey', 'Australia', 'Phillipines',
#        'Indonesia', 'Singapore', 'Qatar', 'Sri Lanka', 'Canada'],
#       dtype='object', name='Country')

# %%
country_values=final_data.Country.value_counts().values #store the zomato orders of the country.

# %%
country_values
# Out:
# array([8652,  434,   80,   60,   60,   60,   40,   34,   24,   22,   21,
#          20,   20,   20,    4])

# %%
#plot the country names and the corresponding the zomato orders
plt.pie(country_values,labels=country_names)
plt.show()

# %% [markdown]
# - Observation: The pie chart is not effective in displaying all the countries with their respective Zomato orders.

# %%
#plot top 3 countries which have highest number of zomato order
plt.pie(country_values[:3],labels=country_names[:3],autopct="%1.2f%%")
plt.show()

# %% [markdown]
# ### From the above pie chart, we can conclude that Zomato has more scope in India. The majority of Zomato orders come from India, followed by the US and the UK

# %%
#combine some feature into single dataset
final_data.groupby(["Aggregate rating","Rating color","Rating text"]).size()
# Out:
# Aggregate rating  Rating color  Rating text
# 0.0               White         Not rated      2148
# 1.8               Red           Poor              1
# 1.9               Red           Poor              2
# 2.0               Red           Poor              7
# 2.1               Red           Poor             15
# 2.2               Red           Poor             27
# 2.3               Red           Poor             47
# 2.4               Red           Poor             87
# 2.5               Orange        Average         110
# 2.6               Orange        Average         191
# 2.7               Orange        Average         250
# 2.8               Orange        Average         315
# 2.9               Orange        Average         381
# 3.0               Orange        Average         468
# 3.1               Orange        Average         519
# 3.2               Orange        Average         522
# 3.3               Orange        Average         483
# ...

# %%
#combine some feature into single dataset
final_data.groupby(["Aggregate rating","Rating color","Rating text"]).size().reset_index()
# Out:
#     Aggregate rating Rating color Rating text     0
# 0                0.0        White   Not rated  2148
# 1                1.8          Red        Poor     1
# 2                1.9          Red        Poor     2
# 3                2.0          Red        Poor     7
# 4                2.1          Red        Poor    15
# 5                2.2          Red        Poor    27
# 6                2.3          Red        Poor    47
# 7                2.4          Red        Poor    87
# 8                2.5       Orange     Average   110
# 9                2.6       Orange     Average   191
# 10               2.7       Orange     Average   250
# 11               2.8       Orange     Average   315
# 12               2.9       Orange     Average   381
# 13               3.0       Orange     Average   468
# 14               3.1       Orange     Average   519
# 15               3.2       Orange     Average   522
# 16               3.3       Orange     Average   483
# ...

# %%
#combine some feature into single dataset
ratings=final_data.groupby(["Aggregate rating","Rating color","Rating text"]).size().reset_index().rename(columns={0:"Rating Count"})

# %%
ratings
# Out:
#     Aggregate rating Rating color Rating text  Rating Count
# 0                0.0        White   Not rated          2148
# 1                1.8          Red        Poor             1
# 2                1.9          Red        Poor             2
# 3                2.0          Red        Poor             7
# 4                2.1          Red        Poor            15
# 5                2.2          Red        Poor            27
# 6                2.3          Red        Poor            47
# 7                2.4          Red        Poor            87
# 8                2.5       Orange     Average           110
# 9                2.6       Orange     Average           191
# 10               2.7       Orange     Average           250
# 11               2.8       Orange     Average           315
# 12               2.9       Orange     Average           381
# 13               3.0       Orange     Average           468
# 14               3.1       Orange     Average           519
# ...

# %% [markdown]
# ### Observations:
# - A rating between 4.5 and 4.9 is considered excellent.
# - A rating between 4.0 and 4.4 is considered very good.
# - A rating between 3.5 and 3.9 is considered good.
# - A rating between 2.5 and 3.4 is considered average.
# - A rating below 2.5 is considered poor.
# - Most of the restaurants have a good rating.

# %% [markdown]
# ### Plot the bar graph for the Rating

# %%
import matplotlib
matplotlib.rcParams["figure.figsize"]=(12,6)
sns.barplot(x="Aggregate rating",y="Rating Count",data=ratings)
# Out:
# <Axes: xlabel='Aggregate rating', ylabel='Rating Count'>

# %%
sns.barplot(x="Aggregate rating",y="Rating Count",hue="Rating text",data=ratings)
# Out:
# <Axes: xlabel='Aggregate rating', ylabel='Rating Count'>

# %%
sns.barplot(x="Aggregate rating",y="Rating Count",hue="Rating color",data=ratings)
# Out:
# <Axes: xlabel='Aggregate rating', ylabel='Rating Count'>

# %%
#match colors in grid in above graph
sns.barplot(x="Aggregate rating",y="Rating Count",hue="Rating color",data=ratings,palette=["white","red","orange","yellow","green","green"])
# Out:
# <Axes: xlabel='Aggregate rating', ylabel='Rating Count'>

# %% [markdown]
# ## Observations
# - The dataset contains the highest number of zero (0) ratings.

# %%
#find out the countries with zero rating
final_data[final_data["Rating color"]=="White"]
# Out:
#       Restaurant ID         Restaurant Name  Country Code            City
# 30          6600060          Sandubas Cafí©            30       Brasí_lia  \
# 58          7305048   Quiosque Chopp Brahma            30  Rio de Janeiro
# 69          6710645        Cantinho da Gula            30      Sí£o Paulo
# 77          6701419           Divino Fogí£o            30      Sí£o Paulo
# 78          6703956             Super Grill            30      Sí£o Paulo
# ...             ...                     ...           ...             ...
# 9109       18277023           Bread & Pasta             1           Noida
# 9110       18313203           Chillies Cafe             1           Noida
# 9111       18254559                Platters             1           Noida
# 9112       18255132               The Grand             1           Noida
# 9351       18273002  Damascena Coffee House           215      Birmingham
#
#                                                 Address
# ...

# %%
final_data[final_data["Rating color"]=="White"].groupby(["Aggregate rating","Country"]).size().reset_index()
# Out:
#    Aggregate rating         Country     0
# 0               0.0          Brazil     5
# 1               0.0           India  2139
# 2               0.0  United Kingdom     1
# 3               0.0   United States     3

# %% [markdown]
# - India have most number of zero ratings.

# %%
#find out the which country use which currency
final_data.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
final_data.groupby(['Country',"Currency"]).size().reset_index()
# Out:
#            Country                Currency     0
# 0        Australia               Dollar($)    24
# 1           Brazil      Brazilian Real(R$)    60
# 2           Canada               Dollar($)     4
# 3            India      Indian Rupees(Rs.)  8652
# 4        Indonesia  Indonesian Rupiah(IDR)    21
# 5      New Zealand           NewZealand($)    40
# 6      Phillipines        Botswana Pula(P)    22
# 7            Qatar         Qatari Rial(QR)    20
# 8        Singapore               Dollar($)    20
# 9     South Africa                 Rand(R)    60
# 10       Sri Lanka   Sri Lankan Rupee(LKR)    20
# 11          Turkey        Turkish Lira(TL)    34
# 12             UAE      Emirati Diram(AED)    60
# 13  United Kingdom              Pounds(£)    80
# 14   United States               Dollar($)   434

# %%
#which country have online delivers
final_data[final_data["Has Online delivery"]=='Yes']
# Out:
#       Restaurant ID                   Restaurant Name  Country Code
# 565         5704255            Famous Dave's Barbecue           214  \
# 566         5701978                    Pizza Di Rocco           214
# 571         5700052  Cho Gao - Crowne Plaza Abu Dhabi           214
# 572         5702418                            Gazebo           214
# 573         5700386   Sangeetha Vegetarian Restaurant           214
# ...             ...                               ...           ...
# 9166          11371                           Chili's             1
# 9168       18292672                        Blue Water             1
# 9170        6507967                   Tales & Spirits             1
# 9171        6506206           18 Degrees Resto Lounge             1
# 9194          96814                    Saffron Mantra             1
#
#               City                                            Address
# 565      Abu Dhabi  Near The One, Level 3, Abu Dhabi Mall, Tourist...  \
# ...

# %%
final_data[final_data["Has Online delivery"]=='Yes'].Country.value_counts()
# Out:
# Country
# India    2423
# UAE        28
# Name: count, dtype: int64

# %% [markdown]
# - Only india and UAE have online deliveries

# %%
final_data.groupby(["Has Online delivery","Country"]).size().reset_index()
# Out:
#    Has Online delivery         Country     0
# 0                   No       Australia    24
# 1                   No          Brazil    60
# 2                   No          Canada     4
# 3                   No           India  6229
# 4                   No       Indonesia    21
# 5                   No     New Zealand    40
# 6                   No     Phillipines    22
# 7                   No           Qatar    20
# 8                   No       Singapore    20
# 9                   No    South Africa    60
# 10                  No       Sri Lanka    20
# 11                  No          Turkey    34
# 12                  No             UAE    32
# 13                  No  United Kingdom    80
# 14                  No   United States   434
# 15                 Yes           India  2423
# 16                 Yes             UAE    28

# %%
final_data['City'].value_counts()
# Out:
# City
# New Delhi           5473
# Gurgaon             1118
# Noida               1080
# Faridabad            251
# Ghaziabad             25
#                     ...
# Panchkula              1
# Mc Millan              1
# Mayfield               1
# Macedon                1
# Vineland Station       1
# Name: count, Length: 141, dtype: int64

# %%
#draw a pie chart for cities
city_names=final_data.City.value_counts().index
city_values=final_data.City.value_counts().values

# %%
plt.pie(city_values,labels=city_names)
plt.show()

# %%
plt.pie(city_values[:5],labels=city_names[:5],autopct="%1.2f%%")
plt.show()

# %% [markdown]
# - Delhi city in india have highest number of Zomato Order

# %%
#find out the top 10 cuisines withe ratings
cuisines=final_data.groupby(["Cuisines","Aggregate rating"]).size().reset_index()

# %%
cuisines
# Out:
#                                        Cuisines  Aggregate rating  0
# 0                                       Afghani               0.0  3
# 1                                       Afghani               2.9  1
# 2                     Afghani, Mughlai, Chinese               0.0  1
# 3                         Afghani, North Indian               0.0  1
# 4     Afghani, North Indian, Pakistani, Arabian               0.0  1
# ...                                         ...               ... ..
# 3919                       Western, Asian, Cafe               4.2  1
# 3920                 Western, Fusion, Fast Food               3.2  1
# 3921                              World Cuisine               4.9  1
# 3922            World Cuisine, Mexican, Italian               4.4  1
# 3923            World Cuisine, Patisserie, Cafe               4.2  1
#
# [3924 rows x 3 columns]

# %%
final_data.Cuisines.value_counts()
# Out:
# Cuisines
# North Indian                                             936
# North Indian, Chinese                                    511
# Chinese                                                  354
# Fast Food                                                354
# North Indian, Mughlai                                    334
#                                                         ...
# Bengali, Fast Food                                         1
# North Indian, Rajasthani, Asian                            1
# Chinese, Thai, Malaysian, Indonesian                       1
# Bakery, Desserts, North Indian, Bengali, South Indian      1
# Italian, World Cuisine                                     1
# Name: count, Length: 1825, dtype: int64

# %%
cusines_names=final_data.Cuisines.value_counts().index
cusines_values=final_data.Cuisines.value_counts().values

# %%
plt.pie(cusines_values[:10],labels=cusines_names[:10],autopct="%1.2f%%")
plt.show()

# %% [markdown]
# - North Indian Cuisine is top most Cuisine among the all cuisines in the data.

# %% [markdown]
# ## Conclusion - Observations
# - The Zomato dataset has no duplicate values and contains a low number of null values.
# - Most of the orders are from India.
# - Only India and the UAE offer online delivery services.
# - Most of the restaurants have a zero rating, with India having the highest number of zero ratings.
# - Each rating is identified by a unique rating color and rating text.
# - Delhi is the city with the most Zomato orders in the dataset.
# - North Indian cuisine is the most popular cuisine in the dataset.
